# %%
import cv2
import os
import pickle
import numpy as np
from mtcnn.mtcnn import MTCNN
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# Placeholder for FaceNet model
class FaceNet:
    def embeddings(self, faces):
        # Implement FaceNet's embedding generation here
        # Make sure it doesn't produce NaN values in embeddings
        # Return valid embeddings with shape (num_samples, embedding_dimension)
        pass

class FACELOADING:
    def __init__(self, directory):
        self.directory = directory
        self.target_size = (100, 100)
        self.X = []
        self.Y = []
        self.detector = MTCNN()
        self.embedder = FaceNet()
        self.encoder = LabelEncoder()
        self.model = RandomForestClassifier(n_estimators=100)  # Use Random Forest Classifier

    def extract_face(self, filename):
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        faces = self.detector.detect_faces(img)
        if faces:
            x, y, w, h = faces[0]['box']
            x, y = abs(x), abs(y)
            face = img[y:y+h, x:x+w]
            face_arr = cv2.resize(face, self.target_size)
            return face_arr
        else:
            return None

    def load_faces(self, dir):
        FACES = []
        for im_name in os.listdir(dir):
            try:
                path = os.path.join(dir, im_name)
                single_face = self.extract_face(path)
                if single_face is not None:
                    FACES.append(single_face)
            except Exception as e:
                pass
        return FACES

    def load_classes(self):
        for sub_dir in os.listdir(self.directory):
            path = os.path.join(self.directory, sub_dir)
            FACES = self.load_faces(path)
            labels = [sub_dir for _ in range(len(FACES))]
            print(f"Loaded successfully: {len(labels)}")
            self.X.extend(FACES)
            self.Y.extend(labels)

        self.encoder.fit(self.Y)
        self.Y_encoded = self.encoder.transform(self.Y)
        self.X_embedded = self.embedder.embeddings(np.asarray(self.X))
        self.model.fit(self.X_embedded, self.Y_encoded)

    def save_model(self, model_file, encoder_file):
        with open(model_file, 'wb') as file:
            pickle.dump(self.model, file)
        with open(encoder_file, 'wb') as file:
            pickle.dump(self.encoder, file)

# Example usage:
if __name__ == "__main__":
    dataset_directory = "C:/Users/Praveen nallasivam/Desktop/codes/New/face_recognization/dataset"
    
    faceloading = FACELOADING(dataset_directory)
    faceloading.load_classes()
    faceloading.save_model('random_forest_model.pkl', 'label_encoder.pkl')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 78
#      75 dataset_directory = "C:/Users/Praveen nallasivam/Desktop/codes/New/face_recognization/dataset"
#      77 faceloading = FACELOADING(dataset_directory)
# ---> 78 faceloading.load_classes()
#      79 faceloading.save_model('random_forest_model.pkl', 'label_encoder.pkl')
#
# Cell In[10], line 65, in FACELOADING.load_classes(self)
#      63 self.Y_encoded = self.encoder.transform(self.Y)
#      64 self.X_embedded = self.embedder.embeddings(np.asarray(self.X))
# ---> 65 self.model.fit(self.X_embedded, self.Y_encoded)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
# ...
